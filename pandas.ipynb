# %% [markdown]
# ### pandas
#
# >Pandas is a power full PYTHON library for manipulation and analysis of data
#
# >Its a open source library
#
# >fast(built on top of numpy),flexible(different source ),productive library

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# #### Series - One dimensional array (data structure)with label

# %%
l1=[1,2,3,4,5]
type(l1)
# Out:
# list

# %%
pd.Series(l1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s=pd.Series(l1,index=["a","b","c","d","e"],name="My series")
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: My series, dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
s.values
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# note:Index does not support mutable operations

# %%
s.index[0]='z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 s.index[0]='z'
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5371, in Index.__setitem__(self, key, value)
#    5369 @final
#    5370 def __setitem__(self, key, value) -> None:
# -> 5371     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
# changing the index of pandas series
s.rename(index={'b':'y'},inplace=True)
s
# Out:
# a    1
# y    2
# c    3
# d    4
# e    5
# Name: My series, dtype: int64

# %% [markdown]
# ### DataFrame -Its a 2d array(just like tables)
# > rows and cols

# %%
dict={'Name':['virat','Rohit','Dhoni','Jadeja','Bumrah','Shami'],
      'Age':[39,40,38,35,45,30],
      'Marks':[90,92,91,93,94,96],
      'Role':['Bats man','batsman','wicket keeper','all rounder','bowler','bowler']}
df=pd.DataFrame(dict)
df
# Out:
#      Name  Age  Marks           Role
# 0   virat   39     90       Bats man
# 1   Rohit   40     92        batsman
# 2   Dhoni   38     91  wicket keeper
# 3  Jadeja   35     93    all rounder
# 4  Bumrah   45     94         bowler
# 5   Shami   30     96         bowler

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#      Name  Age  Marks           Role
# 0   virat   39     90       Bats man
# 1   Rohit   40     92        batsman
# 2   Dhoni   38     91  wicket keeper
# 3  Jadeja   35     93    all rounder
# 4  Bumrah   45     94         bowler

# %%
df.tail(2)
# Out:
#      Name  Age  Marks    Role
# 4  Bumrah   45     94  bowler
# 5   Shami   30     96  bowler

# %%
len(df)
# Out:
# 6

# %%
df.count()
# Out:
# Name     6
# Age      6
# Marks    6
# Role     6
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Marks', 'Role'], dtype='object')

# %%
df['Name']
# Out:
# 0     virat
# 1     Rohit
# 2     Dhoni
# 3    Jadeja
# 4    Bumrah
# 5     Shami
# Name: Name, dtype: object

# %% [markdown]
# single column is defined as series

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# set of rows and columns is defined as DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Name'].value_counts()
# Out:
# Name
# virat     1
# Rohit     1
# Dhoni     1
# Jadeja    1
# Bumrah    1
# Shami     1
# Name: count, dtype: int64

# %%
dict1={'Name':['virat','virat','Dhoni','Jadeja','Bumrah','Shami'],
      'Age':[39,40,38,35,45,30],
      'Marks':[90,92,91,93,94,96],
      'Role':['Bats man','batsman','wicket keeper','all rounder','bowler','bowler']}
df=pd.DataFrame(dict1)
df
# Out:
#      Name  Age  Marks           Role
# 0   virat   39     90       Bats man
# 1   virat   40     92        batsman
# 2   Dhoni   38     91  wicket keeper
# 3  Jadeja   35     93    all rounder
# 4  Bumrah   45     94         bowler
# 5   Shami   30     96         bowler

# %%
df['Name'].value_counts()
# here name virat is repeated two times.
# Out:
# Name
# virat     2
# Dhoni     1
# Jadeja    1
# Bumrah    1
# Shami     1
# Name: count, dtype: int64

# %% [markdown]
# #Day 03
#
# #### Basic  operations:
#
# > Importing dataset from different files
#
# > Importing tabular dataset

# %%
import pandas as pd

# %%
import pandas as pd

stock_df = pd.read_csv(r"C:\Users\klemp\Desktop\Data Analyst 61 G\dataset\ETH_1h.csv")

# %% [markdown]
# ##### In ML coulumn name is call like feature,label,head

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %% [markdown]
# by default head() will return first/top five rows

# %%
stock_df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %% [markdown]
# head(10) it will return first ten rows

# %%
stock_df.head(10)
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# 5  2020-03-13 03-PM  ETHUSD  128.39  128.90  116.06  124.85  7378976.00
# 6  2020-03-13 02-PM  ETHUSD  134.03  137.90  125.50  128.39  3733916.89
# 7  2020-03-13 01-PM  ETHUSD  131.35  140.95  128.99  134.03  9582732.93
# 8  2020-03-13 12-PM  ETHUSD  128.93  134.60  126.95  131.35  3906590.52
# 9  2020-03-13 11-AM  ETHUSD  132.60  133.17  126.01  128.93  3311080.29

# %% [markdown]
# bottom five rows

# %%
stock_df.tail()
# Out:
#                    Date  Symbol    Open    High    Low   Close      Volume
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.0  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.0  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.0  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.0  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.1  275.01   679358.87

# %% [markdown]
# len is used to get number of rows

# %%
len(stock_df)
# Out:
# 23674

# %% [markdown]
# > Access column names of dataframe
#
# >if we use() this parantesis it will become method other wise it is attribute

# %%
stock_df.columns
# Out:
# Index(['Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
#### Accessing a single column
stock_df['Open']
# Out:
# 0        129.94
# 1        119.51
# 2        124.47
# 3        124.08
# 4        124.85
#           ...
# 23669    265.74
# 23670    268.79
# 23671    274.83
# 23672    275.01
# 23673    279.98
# Name: Open, Length: 23674, dtype: float64

# %%
## for accessing  multiple column use array
stock_df[['Open','Symbol','High']]
# Out:
#          Open  Symbol    High
# 0      129.94  ETHUSD  131.82
# 1      119.51  ETHUSD  132.02
# 2      124.47  ETHUSD  124.85
# 3      124.08  ETHUSD  127.42
# 4      124.85  ETHUSD  129.51
# ...       ...     ...     ...
# 23669  265.74  ETHUSD  272.74
# 23670  268.79  ETHUSD  269.90
# 23671  274.83  ETHUSD  274.93
# 23672  275.01  ETHUSD  275.01
# 23673  279.98  ETHUSD  279.99
#
# [23674 rows x 3 columns]

# %% [markdown]
# #Accessing rows using loc and iloc
#
# >if we using iloc it is for index location
#
# >loc is for if index is in name
#
# >loc is label location

# %%
stock_df.index
# Out:
# RangeIndex(start=0, stop=23674, step=1)

# %%
stock_df.columns
# Out:
# Index(['Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %% [markdown]
# apart from int and float other datatype is object

# %%
stock_df.iloc[0]
# Out:
# Date      2020-03-13 08-PM
# Symbol              ETHUSD
# Open                129.94
# High                131.82
# Low                 126.87
# Close               128.71
# Volume          1940673.93
# Name: 0, dtype: object

# %%
stock_df.head(2)
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09

# %%
stock_df.loc[0:10,['Date', 'Symbol', 'Open', 'High']]
# Out:
#                 Date  Symbol    Open    High
# 0   2020-03-13 08-PM  ETHUSD  129.94  131.82
# 1   2020-03-13 07-PM  ETHUSD  119.51  132.02
# 2   2020-03-13 06-PM  ETHUSD  124.47  124.85
# 3   2020-03-13 05-PM  ETHUSD  124.08  127.42
# 4   2020-03-13 04-PM  ETHUSD  124.85  129.51
# 5   2020-03-13 03-PM  ETHUSD  128.39  128.90
# 6   2020-03-13 02-PM  ETHUSD  134.03  137.90
# 7   2020-03-13 01-PM  ETHUSD  131.35  140.95
# 8   2020-03-13 12-PM  ETHUSD  128.93  134.60
# 9   2020-03-13 11-AM  ETHUSD  132.60  133.17
# 10  2020-03-13 10-AM  ETHUSD  133.80  134.99

# %%
stock_df.loc[10,['Date', 'Symbol', 'Open', 'High']]
# Out:
# Date      2020-03-13 10-AM
# Symbol              ETHUSD
# Open                 133.8
# High                134.99
# Name: 10, dtype: object

# %%
stock_df['Open']
# Out:
# 0        129.94
# 1        119.51
# 2        124.47
# 3        124.08
# 4        124.85
#           ...
# 23669    265.74
# 23670    268.79
# 23671    274.83
# 23672    275.01
# 23673    279.98
# Name: Open, Length: 23674, dtype: float64

# %% [markdown]
# if we working with normal 2d array in slicing [][] will happen like this
# > in np.array slicing is [ , ]

# %%
d2=[[1,4,7],[2,4,6],[7,9,8]]
d2
# Out:
# [[1, 4, 7], [2, 4, 6], [7, 9, 8]]

# %%
d2[0][1]
# Out:
# 4

# %%
import numpy as np

# %%
d2=[[1,4,7],[2,4,6],[7,9,8]]
np.array=d2

# %%
d2
# Out:
# [[1, 4, 7], [2, 4, 6], [7, 9, 8]]

# %%
d2[0:2]
# Out:
# [[1, 4, 7], [2, 4, 6]]

# %% [markdown]
# slicing

# %%
stock_df.loc[10,'Date': 'High'] # in number slicing last one is exclusive but in string both are inclusive
# Out:
# Date      2020-03-13 10-AM
# Symbol              ETHUSD
# Open                 133.8
# High                134.99
# Name: 10, dtype: object

# %% [markdown]
# ##when the exact position is known but label name is unknown in that time we use iloc

# %% [markdown]
# iloc is the index based location

# %%
stock_df.iloc[0]
# Out:
# Date      2020-03-13 08-PM
# Symbol              ETHUSD
# Open                129.94
# High                131.82
# Low                 126.87
# Close               128.71
# Volume          1940673.93
# Name: 0, dtype: object

# %%
df.iloc[2,0:7] #slicing of column index
# Out:
# Date      2020-03-13 06-PM
# Symbol              ETHUSD
# Open                124.47
# High                124.85
# Low                  115.5
# Close               119.51
# Volume          4898735.81
# Name: 2, dtype: object

# %%
stock_df.iloc[2,2]# row index and column index
# Out:
# np.float64(124.47)

# %%
stock_df.index
# Out:
# RangeIndex(start=0, stop=23674, step=1)

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
import numpy as np

print(type(np.array))
print(np.array)
# Out:
# <class 'builtin_function_or_method'>
# <built-in function array>

# %%
stock_df.iloc[1:6,2:6]
# Out:
#      Open    High     Low   Close
# 1  119.51  132.02  117.10  129.94
# 2  124.47  124.85  115.50  119.51
# 3  124.08  127.42  121.63  124.47
# 4  124.85  129.51  120.17  124.08
# 5  128.39  128.90  116.06  124.85

# %%
f1=stock_df['High']>130
stock_df[f1]
stock_gt_130=stock_df[f1]

# %%
stock_gt_130.reset_index(drop=True,inplace=True)

# %%
stock_gt_130
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 02-PM  ETHUSD  134.03  137.90  125.50  128.39  3733916.89
# 3      2020-03-13 01-PM  ETHUSD  131.35  140.95  128.99  134.03  9582732.93
# 4      2020-03-13 12-PM  ETHUSD  128.93  134.60  126.95  131.35  3906590.52
# ...                 ...     ...     ...     ...     ...     ...         ...
# 21608  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 21609  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 21610  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 21611  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 21612  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [21613 rows x 7 columns]

# %% [markdown]
# Adding a new column

# %%
stock_df['random_col']=list(range(1,len(stock_df)+1))

# %%
stock_df.index
# Out:
# RangeIndex(start=0, stop=23674, step=1)

# %% [markdown]
# Droping the columns
# here axis=1 is column and 0 is row

# %%
len(stock_df)
# Out:
# 23674

# %%
stock_df['Random_col']=list(range(1,len(stock_df)+1))

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume  \
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#        random_col  Random_col
# ...

# %%
stock_df.drop(columns=['Random_col'],inplace=True)

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume  \
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#        random_col
# 0               1
# ...

# %%
stock_df.drop(columns=['Open','High'],inplace=True)

# %%
stock_df
# Out:
#                    Date  Symbol     Low   Close      Volume  random_col
# 0      2020-03-13 08-PM  ETHUSD  126.87  128.71  1940673.93           1
# 3      2020-03-13 05-PM  ETHUSD  121.63  124.47  2753450.92           4
# 4      2020-03-13 04-PM  ETHUSD  120.17  124.08  4461424.71           5
# 5      2020-03-13 03-PM  ETHUSD  116.06  124.85  7378976.00           6
# 6      2020-03-13 02-PM  ETHUSD  125.50  128.39  3733916.89           7
# ...                 ...     ...     ...     ...         ...         ...
# 23668  2017-07-01 04-PM  ETHUSD  267.60  268.00  1287300.75       23669
# 23669  2017-07-01 03-PM  ETHUSD  265.00  272.57  1500282.55       23670
# 23670  2017-07-01 02-PM  ETHUSD  265.00  265.74  1702536.85       23671
# 23671  2017-07-01 01-PM  ETHUSD  265.00  268.79  3010787.99       23672
# 23673  2017-07-01 11-AM  ETHUSD  272.10  275.01   679358.87       23674
#
# [23671 rows x 6 columns]

# %%
stock_df.drop(23672,axis=0,inplace=True)

# %%
len(stock_df)
# Out:
# 23673

# %%
stock_df.drop([1,2],axis=0,inplace=True)

# %%
len(stock_df)
# Out:
# 23671
